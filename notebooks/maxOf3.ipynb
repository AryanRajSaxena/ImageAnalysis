# %%
# Importing Image from PIL package
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
import plotly.express as px
import pandas as pd

# %%
max_df = pd.read_csv(R'D:\sohamSir\image_analysis_and_color_estimation\ImageAnalysis\data\processed\max_redness_in_3.csv')
min_df = pd.read_csv(R'D:\sohamSir\image_analysis_and_color_estimation\ImageAnalysis\data\processed\min_redness_in_3.csv')

# %%
max_df
# Out:
#             t0          t1          t2          t3          t4          t5  \
# 0   174.157211  148.930557  158.097656  149.411804  152.927124  147.769058
# 1   170.991592  147.902191  152.237106  145.284668  145.284668  153.717041
# 2   176.575409  143.141098  147.082687  138.151642  146.391556  145.311493
# 3   176.778229  150.152863  156.019012  149.304276  159.651855  153.585602
# 4   193.776154  149.646255  157.000137  148.187744  160.430023  158.065460
# 5   180.415909  148.653030  152.222366  150.072342  159.636887  149.347412
# 6   169.585434  151.084671  156.441406  142.016113  156.661453  145.115494
# 7   136.624313  153.073608  147.365768  149.386795  149.395798  150.042175
# 8   138.784805  136.344925  142.512360  146.937042  147.306595  145.644043
# 9   146.299042  139.168533  149.105133  150.599243  143.769287  147.789291
# 10  148.866302  147.656662  150.131577  150.847504  150.382248  150.738373
# ...

# %%
red = 220
green = 120
blue = 25

# %%
if red in range(200,255) and green in range(100,165) and blue in range(0,50):
    print('orange')
# Out:
# red
