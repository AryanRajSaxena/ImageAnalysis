# %% [markdown]
# Testing on Individual image

# %%
# Importing Image from PIL package
from PIL import Image
import matplotlib.pyplot as plt
import cv2
import numpy as np
import os
import plotly.express as px
import pandas as pd

# %%
def color(image):
    redness = []
    for i in range(0,image.size[0]):
        for j in range(0,image.size[1]):
            redness.append(image[1].getpixel((i,j))[1] + image[1].getpixel((i,j))[0])

    avg_redness = sum(redness) / len(redness)
    return avg_redness

def load_image(image_path):
    im = Image.open(image_path)
    im =im.resize((256,256))
    crop_box = (100, 100, 150, 150)
    img_cropped = im.crop(crop_box)
    return [img_cropped, im]

def show_image(image):
    img_resized = np.array(image)
    # plt.grid()
    plt.imshow(img_resized)
    plt.show()

# %%
image_path = R"D:\sohamSir\image_analysis_and_color_estimation\ImageAnalysis\data\raw\RGB Compatible Quality\220 ug RGB\T1-1.tif"

# %%
new = []

# %%
img = load_image(image_path)
# show_image(img[1])
img[1]
# intensity = color(img[1])
# new.append(intensity)
# Out:
# <PIL.Image.Image image mode=RGB size=256x256>

# %%
image = cv2.imread(R"D:\sohamSir\image_analysis_and_color_estimation\ImageAnalysis\data\processed\T0-1.jpg")

# %%
hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

# %%
plt.imshow(hsv_image)

# %%
lower_orange = np.array([10, 100, 100])
upper_orange = np.array([40, 255, 255])

# %%
mask = cv2.inRange(hsv_image, lower_orange, upper_orange)

# %%
orange_image = cv2.bitwise_and(image, image, mask=mask)

# %%
plt.imshow(orange_image)

# %%
gray_orange = cv2.cvtColor(orange_image, cv2.COLOR_BGR2GRAY)

# %%
average_brightness = np.mean(gray_orange)

# %%
min_value = np.max(gray_orange)

# %%
average_brightness
# Out:
# 9.871104

# %%
min_value
# Out:
# 120

# %%
image_path = cv2.imread(R"D:\sohamSir\image_analysis_and_color_estimation\ImageAnalysis\data\processed\T0-1.jpg")

def img_trf(image):
  def find_most_frequent_color(image):
    hsv_image = cv2.cvtColor(image, cv2.COLOR_BGR2HSV)

    hsv_pixels = hsv_image.reshape((-1, 3))

    unique_colors, counts = np.unique(hsv_pixels, axis=0, return_counts=True)

    max_color_index = np.argmax(counts)

    return unique_colors[max_color_index][0]
  # Find the most frequent color (assuming it's the orange square)
  most_frequent_orange_hue = find_most_frequent_color(image)

  # Print the "maximum orange" hue value (assuming higher hue corresponds to brighter orange)
  print("Hue value of the most frequent orange color:", most_frequent_orange_hue)

  orange_pixel_range = np.array([most_frequent_orange_hue-5, 100, 100])  # Adjust range as needed
  upper_orange_range = np.array([most_frequent_orange_hue+5, 200, 200])

  mask = cv2.inRange(hsv_image, orange_pixel_range, upper_orange_range)
  orange_image = cv2.bitwise_and(image, image, mask=mask)
  temp_image = cv2.cvtColor(orange_image, cv2.COLOR_BGR2RGB)
  return plt.imshow(temp_image)

img_trf(image_path)
# Out:
# Hue value of the most frequent orange color: 9

# %%
show_image(img[1])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 show_image(img[1])
#
# NameError: name 'img' is not defined
